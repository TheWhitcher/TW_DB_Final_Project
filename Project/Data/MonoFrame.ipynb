# %%
#Import basic data tools
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#Create dataframes from the different csv
co2 = 'annual-co2-emissions-per-country.csv'
gdpCapita = 'gdp-per-capita.csv'
methane = 'methane-emissions.csv'
nitrous = 'nitrous-oxide-emissions.csv'
popStat = 'population-and-demography.csv'
ghg = 'total-ghg-emissions.csv'

dfCo2 = pd.read_csv(co2)
dfGdp = pd.read_csv(gdpCapita)
dfMet = pd.read_csv(methane)
dfNit = pd.read_csv(nitrous)
dfPop = pd.read_csv(popStat)
dfGhg = pd.read_csv(ghg)

# %%
#List of the G20 Countries
G20 = ['Argentina', 
       'Australia', 
       'Brazil', 
       'Canada', 
       'China', 
       'France', 
       'Germany', 
       'India', 
       'Indonesia', 
       'Italy',
       'Japan',
       'Mexico',
       'South Korea',
       'Russia',
       'Saudi Arabia',
       'South Africa',
       'Turkey',
       'United Kingdom',
       'United States',
       'Eropean Union',
       'World',]

# %%
dfPop = dfPop[(dfPop["Country name"].isin(G20))]
dfPop
# Out:
#       Country name  Year  Population  \
# 648      Argentina  1950    17017748
# 649      Argentina  1951    17354614
# 650      Argentina  1952    17693856
# 651      Argentina  1953    18032748
# 652      Argentina  1954    18369248
# ...            ...   ...         ...
# 18067        World  2017  7599822300
# 18068        World  2018  7683790000
# 18069        World  2019  7764951000
# 18070        World  2020  7840953000
# 18071        World  2021  7909295000
#
#        Population of children under the age of 1  \
# 648                                     416798.0
# 649                                     424587.0
# 650                                     431231.0
# 651                                     437147.0
# 652                                     441999.0
# ...                                          ...
# 18067                                139420590.0
# 18068                                137690030.0
# 18069                                135471330.0
# ...

# %%
#Trim the data of the dfPop
dfCo2 = dfCo2[(dfCo2["Entity"].isin(G20))]
dfGdp = dfGdp[(dfGdp["Entity"].isin(G20))]
dfMet = dfMet[(dfMet["Entity"].isin(G20))]
dfNit = dfNit[(dfNit["Entity"].isin(G20))]
dfGhg = dfGhg[(dfGhg["Entity"].isin(G20))]

# %%
dfPop
# Out:
#       Country name  Year  Population  \
# 648      Argentina  1950    17017748
# 649      Argentina  1951    17354614
# 650      Argentina  1952    17693856
# 651      Argentina  1953    18032748
# 652      Argentina  1954    18369248
# ...            ...   ...         ...
# 18067        World  2017  7599822300
# 18068        World  2018  7683790000
# 18069        World  2019  7764951000
# 18070        World  2020  7840953000
# 18071        World  2021  7909295000
#
#        Population of children under the age of 1  \
# 648                                     416798.0
# 649                                     424587.0
# 650                                     431231.0
# 651                                     437147.0
# 652                                     441999.0
# ...                                          ...
# 18067                                139420590.0
# 18068                                137690030.0
# 18069                                135471330.0
# ...

# %%
#Trim the dfPop to only have the population
dfPop = dfPop[["Country name", "Year", "Population"]]
dfPop
# Out:
#       Country name  Year  Population
# 648      Argentina  1950    17017748
# 649      Argentina  1951    17354614
# 650      Argentina  1952    17693856
# 651      Argentina  1953    18032748
# 652      Argentina  1954    18369248
# ...            ...   ...         ...
# 18067        World  2017  7599822300
# 18068        World  2018  7683790000
# 18069        World  2019  7764951000
# 18070        World  2020  7840953000
# 18071        World  2021  7909295000
#
# [1440 rows x 3 columns]

# %%
#Add the population to the data frame
df = pd.merge(
    left = dfCo2,
    right = dfPop,
    left_on = ["Entity", "Year"],
    right_on = ["Country name", "Year"],
    how = 'inner'
)
df
# Out:
#          Entity      Code  Year  Annual CO₂ emissions Country name  Population
# 0     Argentina       ARG  1950          2.992119e+07    Argentina    17017748
# 1     Argentina       ARG  1951          3.496292e+07    Argentina    17354614
# 2     Argentina       ARG  1952          3.609512e+07    Argentina    17693856
# 3     Argentina       ARG  1953          3.513474e+07    Argentina    18032748
# 4     Argentina       ARG  1954          3.675036e+07    Argentina    18369248
# ...         ...       ...   ...                   ...          ...         ...
# 1435      World  OWID_WRL  2017          3.609674e+10        World  7599822300
# 1436      World  OWID_WRL  2018          3.682651e+10        World  7683790000
# 1437      World  OWID_WRL  2019          3.708256e+10        World  7764951000
# 1438      World  OWID_WRL  2020          3.526409e+10        World  7840953000
# 1439      World  OWID_WRL  2021          3.712385e+10        World  7909295000
#
# [1440 rows x 6 columns]

# %%
#Clean the Merge
df= df.drop('Country name', axis=1)

# %%
#Check all of the frames
df
# Out:
#          Entity      Code  Year  Annual CO₂ emissions  Population
# 0     Argentina       ARG  1950          2.992119e+07    17017748
# 1     Argentina       ARG  1951          3.496292e+07    17354614
# 2     Argentina       ARG  1952          3.609512e+07    17693856
# 3     Argentina       ARG  1953          3.513474e+07    18032748
# 4     Argentina       ARG  1954          3.675036e+07    18369248
# ...         ...       ...   ...                   ...         ...
# 1435      World  OWID_WRL  2017          3.609674e+10  7599822300
# 1436      World  OWID_WRL  2018          3.682651e+10  7683790000
# 1437      World  OWID_WRL  2019          3.708256e+10  7764951000
# 1438      World  OWID_WRL  2020          3.526409e+10  7840953000
# 1439      World  OWID_WRL  2021          3.712385e+10  7909295000
#
# [1440 rows x 5 columns]

# %%
#Merge the df and dfCdp

df = pd.merge(
    df,
    dfGdp,
    left_on = ["Entity", "Year"],
    right_on = ["Entity", "Year"],  
    how = 'inner'
)

df
# Out:
#          Entity    Code_x  Year  Annual CO₂ emissions  Population    Code_y  \
# 0     Argentina       ARG  1950          2.992119e+07    17017748       ARG
# 1     Argentina       ARG  1951          3.496292e+07    17354614       ARG
# 2     Argentina       ARG  1952          3.609512e+07    17693856       ARG
# 3     Argentina       ARG  1953          3.513474e+07    18032748       ARG
# 4     Argentina       ARG  1954          3.675036e+07    18369248       ARG
# ...         ...       ...   ...                   ...         ...       ...
# 1306      World  OWID_WRL  2000          2.545362e+10  6148899000  OWID_WRL
# 1307      World  OWID_WRL  2010          3.336435e+10  6985603000  OWID_WRL
# 1308      World  OWID_WRL  2016          3.552419e+10  7513474000  OWID_WRL
# 1309      World  OWID_WRL  2017          3.609674e+10  7599822300  OWID_WRL
# 1310      World  OWID_WRL  2018          3.682651e+10  7683790000  OWID_WRL
#
#       GDP per capita 417485-annotations
# ...

# %%
#Clean the Merge

df= df.drop('Code_y', axis=1)
df= df.drop('417485-annotations', axis=1)

df
# Out:
#          Entity    Code_x  Year  Annual CO₂ emissions  Population  \
# 0     Argentina       ARG  1950          2.992119e+07    17017748
# 1     Argentina       ARG  1951          3.496292e+07    17354614
# 2     Argentina       ARG  1952          3.609512e+07    17693856
# 3     Argentina       ARG  1953          3.513474e+07    18032748
# 4     Argentina       ARG  1954          3.675036e+07    18369248
# ...         ...       ...   ...                   ...         ...
# 1306      World  OWID_WRL  2000          2.545362e+10  6148899000
# 1307      World  OWID_WRL  2010          3.336435e+10  6985603000
# 1308      World  OWID_WRL  2016          3.552419e+10  7513474000
# 1309      World  OWID_WRL  2017          3.609674e+10  7599822300
# 1310      World  OWID_WRL  2018          3.682651e+10  7683790000
#
#       GDP per capita
# 0           7949.000
# 1           8086.000
# 2           7519.000
# 3           7769.000
# 4           7938.000
# ...              ...
# ...

# %%
#Merge dfMet and dfNit
df2 = pd.merge(
    dfNit,
    dfMet,
    left_on = ["Entity", "Year"],
    right_on = ["Entity", "Year"],  
    how = 'inner'
)

df2
# Out:
#          Entity    Code_x  Year  Annual nitrous oxide emissions    Code_y  \
# 0     Argentina       ARG  1851                    7.562959e+05       ARG
# 1     Argentina       ARG  1852                    7.679762e+05       ARG
# 2     Argentina       ARG  1853                    7.792992e+05       ARG
# 3     Argentina       ARG  1854                    7.901285e+05       ARG
# 4     Argentina       ARG  1855                    8.003274e+05       ARG
# ...         ...       ...   ...                             ...       ...
# 3415      World  OWID_WRL  2017                    2.875266e+09  OWID_WRL
# 3416      World  OWID_WRL  2018                    2.870180e+09  OWID_WRL
# 3417      World  OWID_WRL  2019                    2.885550e+09  OWID_WRL
# 3418      World  OWID_WRL  2020                    2.917279e+09  OWID_WRL
# 3419      World  OWID_WRL  2021                    2.968141e+09  OWID_WRL
#
#       Annual methane emissions
# 0                 4.367059e+06
# ...

# %%
#Clean the Merge
df2= df2.drop('Code_y', axis=1)

df2
# Out:
#          Entity    Code_x  Year  Annual nitrous oxide emissions  \
# 0     Argentina       ARG  1851                    7.562959e+05
# 1     Argentina       ARG  1852                    7.679762e+05
# 2     Argentina       ARG  1853                    7.792992e+05
# 3     Argentina       ARG  1854                    7.901285e+05
# 4     Argentina       ARG  1855                    8.003274e+05
# ...         ...       ...   ...                             ...
# 3415      World  OWID_WRL  2017                    2.875266e+09
# 3416      World  OWID_WRL  2018                    2.870180e+09
# 3417      World  OWID_WRL  2019                    2.885550e+09
# 3418      World  OWID_WRL  2020                    2.917279e+09
# 3419      World  OWID_WRL  2021                    2.968141e+09
#
#       Annual methane emissions
# 0                 4.367059e+06
# 1                 4.484928e+06
# 2                 4.602804e+06
# 3                 4.720688e+06
# 4                 4.838581e+06
# ...

# %%
#Merge df2 and dfGhg into df3
df3 = pd.merge(
    df2,
    dfGhg,
    left_on = ["Entity", "Year"],
    right_on = ["Entity", "Year"],
    how = 'inner'
)

df3
# Out:
#          Entity    Code_x  Year  Annual nitrous oxide emissions  \
# 0     Argentina       ARG  1851                    7.562959e+05
# 1     Argentina       ARG  1852                    7.679762e+05
# 2     Argentina       ARG  1853                    7.792992e+05
# 3     Argentina       ARG  1854                    7.901285e+05
# 4     Argentina       ARG  1855                    8.003274e+05
# ...         ...       ...   ...                             ...
# 3415      World  OWID_WRL  2017                    2.875266e+09
# 3416      World  OWID_WRL  2018                    2.870180e+09
# 3417      World  OWID_WRL  2019                    2.885550e+09
# 3418      World  OWID_WRL  2020                    2.917279e+09
# 3419      World  OWID_WRL  2021                    2.968141e+09
#
#       Annual methane emissions      Code  Annual greenhouse gas emissions
# 0                 4.367059e+06       ARG                     3.599866e+07
# ...

# %%
#Clear merge
df3= df3.drop('Code', axis=1)

df3
# Out:
#          Entity    Code_x  Year  Annual nitrous oxide emissions  \
# 0     Argentina       ARG  1851                    7.562959e+05
# 1     Argentina       ARG  1852                    7.679762e+05
# 2     Argentina       ARG  1853                    7.792992e+05
# 3     Argentina       ARG  1854                    7.901285e+05
# 4     Argentina       ARG  1855                    8.003274e+05
# ...         ...       ...   ...                             ...
# 3415      World  OWID_WRL  2017                    2.875266e+09
# 3416      World  OWID_WRL  2018                    2.870180e+09
# 3417      World  OWID_WRL  2019                    2.885550e+09
# 3418      World  OWID_WRL  2020                    2.917279e+09
# 3419      World  OWID_WRL  2021                    2.968141e+09
#
#       Annual methane emissions  Annual greenhouse gas emissions
# 0                 4.367059e+06                     3.599866e+07
# 1                 4.484928e+06                     3.715413e+07
# ...

# %%
#Merge df and df3 into df4
df = pd.merge(
    df,
    df3,
    left_on = ["Entity", "Year"],
    right_on = ["Entity", "Year"],
    how = 'inner'
)

df
# Out:
#          Entity  Code_x_x  Year  Annual CO₂ emissions  Population  \
# 0     Argentina       ARG  1950          2.992119e+07    17017748
# 1     Argentina       ARG  1951          3.496292e+07    17354614
# 2     Argentina       ARG  1952          3.609512e+07    17693856
# 3     Argentina       ARG  1953          3.513474e+07    18032748
# 4     Argentina       ARG  1954          3.675036e+07    18369248
# ...         ...       ...   ...                   ...         ...
# 1306      World  OWID_WRL  2000          2.545362e+10  6148899000
# 1307      World  OWID_WRL  2010          3.336435e+10  6985603000
# 1308      World  OWID_WRL  2016          3.552419e+10  7513474000
# 1309      World  OWID_WRL  2017          3.609674e+10  7599822300
# 1310      World  OWID_WRL  2018          3.682651e+10  7683790000
#
#       GDP per capita  Code_x_y  Annual nitrous oxide emissions  \
# 0           7949.000       ARG                    1.650561e+07
# ...

# %%
#Clean up the merge
df= df.drop('Code_x_y', axis=1)

# %%
#Create the CO2 emmission per person column
df["Per Capita CO₂"] = df["Annual CO₂ emissions"] /  df["Population"]
df
# Out:
#          Entity  Code_x_x  Year  Annual CO₂ emissions  Population  \
# 0     Argentina       ARG  1950          2.992119e+07    17017748
# 1     Argentina       ARG  1951          3.496292e+07    17354614
# 2     Argentina       ARG  1952          3.609512e+07    17693856
# 3     Argentina       ARG  1953          3.513474e+07    18032748
# 4     Argentina       ARG  1954          3.675036e+07    18369248
# ...         ...       ...   ...                   ...         ...
# 1306      World  OWID_WRL  2000          2.545362e+10  6148899000
# 1307      World  OWID_WRL  2010          3.336435e+10  6985603000
# 1308      World  OWID_WRL  2016          3.552419e+10  7513474000
# 1309      World  OWID_WRL  2017          3.609674e+10  7599822300
# 1310      World  OWID_WRL  2018          3.682651e+10  7683790000
#
#       GDP per capita  Annual nitrous oxide emissions  \
# 0           7949.000                    1.650561e+07
# 1           8086.000                    1.715333e+07
# ...

# %%
#Create the GDP column
df["GDP"] = df["GDP per capita"] * df["Population"]
df
# Out:
#          Entity  Code_x_x  Year  Annual CO₂ emissions  Population  \
# 0     Argentina       ARG  1950          2.992119e+07    17017748
# 1     Argentina       ARG  1951          3.496292e+07    17354614
# 2     Argentina       ARG  1952          3.609512e+07    17693856
# 3     Argentina       ARG  1953          3.513474e+07    18032748
# 4     Argentina       ARG  1954          3.675036e+07    18369248
# ...         ...       ...   ...                   ...         ...
# 1306      World  OWID_WRL  2000          2.545362e+10  6148899000
# 1307      World  OWID_WRL  2010          3.336435e+10  6985603000
# 1308      World  OWID_WRL  2016          3.552419e+10  7513474000
# 1309      World  OWID_WRL  2017          3.609674e+10  7599822300
# 1310      World  OWID_WRL  2018          3.682651e+10  7683790000
#
#       GDP per capita  Annual nitrous oxide emissions  \
# 0           7949.000                    1.650561e+07
# 1           8086.000                    1.715333e+07
# ...

# %%
#Create the emissions per dollard column.
df["Econ Intensity"] = df["Annual CO₂ emissions"] / df["GDP"]
df
# Out:
#          Entity  Code_x_x  Year  Annual CO₂ emissions  Population  \
# 0     Argentina       ARG  1950          2.992119e+07    17017748
# 1     Argentina       ARG  1951          3.496292e+07    17354614
# 2     Argentina       ARG  1952          3.609512e+07    17693856
# 3     Argentina       ARG  1953          3.513474e+07    18032748
# 4     Argentina       ARG  1954          3.675036e+07    18369248
# ...         ...       ...   ...                   ...         ...
# 1306      World  OWID_WRL  2000          2.545362e+10  6148899000
# 1307      World  OWID_WRL  2010          3.336435e+10  6985603000
# 1308      World  OWID_WRL  2016          3.552419e+10  7513474000
# 1309      World  OWID_WRL  2017          3.609674e+10  7599822300
# 1310      World  OWID_WRL  2018          3.682651e+10  7683790000
#
#       GDP per capita  Annual nitrous oxide emissions  \
# 0           7949.000                    1.650561e+07
# 1           8086.000                    1.715333e+07
# ...

# %%
dfworld = df[df['Entity']=='World'][['Year','Annual CO₂ emissions']]
dfworld
# Out:
#       Year  Annual CO₂ emissions
# 1301  1950          6.003272e+09
# 1302  1960          9.387668e+09
# 1303  1970          1.489872e+10
# 1304  1980          1.950126e+10
# 1305  1990          2.275748e+10
# 1306  2000          2.545362e+10
# 1307  2010          3.336435e+10
# 1308  2016          3.552419e+10
# 1309  2017          3.609674e+10
# 1310  2018          3.682651e+10

# %%
#Merge df and dfworld into df
df = pd.merge(
    df,
    dfworld,
    on='Year',
    how='left',
    )

df
# Out:
#          Entity  Code_x_x  Year  Annual CO₂ emissions_x  Population  \
# 0     Argentina       ARG  1950            2.992119e+07    17017748
# 1     Argentina       ARG  1951            3.496292e+07    17354614
# 2     Argentina       ARG  1952            3.609512e+07    17693856
# 3     Argentina       ARG  1953            3.513474e+07    18032748
# 4     Argentina       ARG  1954            3.675036e+07    18369248
# ...         ...       ...   ...                     ...         ...
# 1306      World  OWID_WRL  2000            2.545362e+10  6148899000
# 1307      World  OWID_WRL  2010            3.336435e+10  6985603000
# 1308      World  OWID_WRL  2016            3.552419e+10  7513474000
# 1309      World  OWID_WRL  2017            3.609674e+10  7599822300
# 1310      World  OWID_WRL  2018            3.682651e+10  7683790000
#
#       GDP per capita  Annual nitrous oxide emissions  \
# 0           7949.000                    1.650561e+07
# ...

# %%
df["CO₂ Global Share"] = df["Annual CO₂ emissions_x"] / df["Annual CO₂ emissions_y"] * 100
df
# Out:
#          Entity  Code_x_x  Year  Annual CO₂ emissions_x  Population  \
# 0     Argentina       ARG  1950            2.992119e+07    17017748
# 1     Argentina       ARG  1951            3.496292e+07    17354614
# 2     Argentina       ARG  1952            3.609512e+07    17693856
# 3     Argentina       ARG  1953            3.513474e+07    18032748
# 4     Argentina       ARG  1954            3.675036e+07    18369248
# ...         ...       ...   ...                     ...         ...
# 1306      World  OWID_WRL  2000            2.545362e+10  6148899000
# 1307      World  OWID_WRL  2010            3.336435e+10  6985603000
# 1308      World  OWID_WRL  2016            3.552419e+10  7513474000
# 1309      World  OWID_WRL  2017            3.609674e+10  7599822300
# 1310      World  OWID_WRL  2018            3.682651e+10  7683790000
#
#       GDP per capita  Annual nitrous oxide emissions  \
# 0           7949.000                    1.650561e+07
# ...

# %%
df = df.drop("Annual CO₂ emissions_y", axis =1)

# %%
df
# Out:
#          Entity  Code_x_x  Year  Annual CO₂ emissions_x  Population  \
# 0     Argentina       ARG  1950            2.992119e+07    17017748
# 1     Argentina       ARG  1951            3.496292e+07    17354614
# 2     Argentina       ARG  1952            3.609512e+07    17693856
# 3     Argentina       ARG  1953            3.513474e+07    18032748
# 4     Argentina       ARG  1954            3.675036e+07    18369248
# ...         ...       ...   ...                     ...         ...
# 1306      World  OWID_WRL  2000            2.545362e+10  6148899000
# 1307      World  OWID_WRL  2010            3.336435e+10  6985603000
# 1308      World  OWID_WRL  2016            3.552419e+10  7513474000
# 1309      World  OWID_WRL  2017            3.609674e+10  7599822300
# 1310      World  OWID_WRL  2018            3.682651e+10  7683790000
#
#       GDP per capita  Annual nitrous oxide emissions  \
# 0           7949.000                    1.650561e+07
# ...

# %%
df["Nitrous oxide per population"] = df["Annual nitrous oxide emissions"] / df["Population"]
df
# Out:
#          Entity  Code_x_x  Year  Annual CO₂ emissions_x  Population  \
# 0     Argentina       ARG  1950            2.992119e+07    17017748
# 1     Argentina       ARG  1951            3.496292e+07    17354614
# 2     Argentina       ARG  1952            3.609512e+07    17693856
# 3     Argentina       ARG  1953            3.513474e+07    18032748
# 4     Argentina       ARG  1954            3.675036e+07    18369248
# ...         ...       ...   ...                     ...         ...
# 1306      World  OWID_WRL  2000            2.545362e+10  6148899000
# 1307      World  OWID_WRL  2010            3.336435e+10  6985603000
# 1308      World  OWID_WRL  2016            3.552419e+10  7513474000
# 1309      World  OWID_WRL  2017            3.609674e+10  7599822300
# 1310      World  OWID_WRL  2018            3.682651e+10  7683790000
#
#       GDP per capita  Annual nitrous oxide emissions  \
# 0           7949.000                    1.650561e+07
# ...

# %%
df["Methane per population"] = df["Annual methane emissions"] / df["Population"]
df
# Out:
#          Entity  Code_x_x  Year  Annual CO₂ emissions_x  Population  \
# 0     Argentina       ARG  1950            2.992119e+07    17017748
# 1     Argentina       ARG  1951            3.496292e+07    17354614
# 2     Argentina       ARG  1952            3.609512e+07    17693856
# 3     Argentina       ARG  1953            3.513474e+07    18032748
# 4     Argentina       ARG  1954            3.675036e+07    18369248
# ...         ...       ...   ...                     ...         ...
# 1306      World  OWID_WRL  2000            2.545362e+10  6148899000
# 1307      World  OWID_WRL  2010            3.336435e+10  6985603000
# 1308      World  OWID_WRL  2016            3.552419e+10  7513474000
# 1309      World  OWID_WRL  2017            3.609674e+10  7599822300
# 1310      World  OWID_WRL  2018            3.682651e+10  7683790000
#
#       GDP per capita  Annual nitrous oxide emissions  \
# 0           7949.000                    1.650561e+07
# ...

# %%
df.to_csv('prototype_csv.csv', index=False)

# %%
#Anual CO2 emissions per GDP.

#Select the countries to be displayed.
#Palce holder
countries = ["Canada", "United States", "United Kingdom", "China", "Japan", "World"]

#Plot the dataframe with the seleced entities.
df_plot = df[(df["Entity"].isin(countries))]

#Select the style of the graph.
plt.style.use("ggplot")

fig , axs = plt.subplots() 

sns.lineplot(
    data = df_plot,
    x="Year",
    y="CO₂ Global Share",
    hue="Entity",
    ax=axs,
)
plt.title("Annual CO₂ Share of Gobal Emission")
#plt.savefig("df annual CO₂ Share")
# Out:
# Text(0.5, 1.0, 'Annual CO₂ Share of Gobal Emission')

# %%
#Anual CO2 emissions per GDP.

#Select the countries to be displayed.
#Palce holder
countries = ["Canada", "United States", "United Kingdom", "China", "Japan"]

#Plot the dataframe with the seleced entities.
df_plot = df[(df["Entity"].isin(countries))]

#Select the style of the graph.
plt.style.use("ggplot")

fig , axs = plt.subplots() 

sns.lineplot(
    data = df_plot,
    x="Year",
    y="Econ Intensity",
    hue="Entity",
    ax=axs,
)
plt.title("Annual CO₂ Emissions per Dollard")
#plt.savefig("annual CO₂ emissions per Dollard")
# Out:
# Text(0.5, 1.0, 'Annual CO₂ Emissions per Dollard')

# %%
#Anual CO2 emissions per capita.

#Select the countries to be displayed.
#Palce holder
countries = ["Canada", "United States", "United Kingdom", "China", "Japan"]

#Plot the dataframe with the seleced entities.
df_plot = df[(df["Entity"].isin(countries))]

#Select the style of the graph.
plt.style.use("ggplot")

fig , axs = plt.subplots() 

sns.lineplot(
    data = df_plot,
    x="Year",
    y="Per Capita CO₂",
    hue="Entity",
    ax=axs,
)
plt.title("Annual CO₂ Emissions per Capita")
#plt.savefig("annual CO₂ emissions per Capita")
# Out:
# Text(0.5, 1.0, 'Annual CO₂ Emissions per Capita')

# %%
#Anual CO2 emissions per country.

#Select the countries to be displayed.
#Palce holder
countries = ["Canada", "United States", "United Kingdom", "China", "Japan"]

#Plot the dataframe with the seleced entities.
df_plot = df[(df["Entity"].isin(countries))]

#Select the style of the graph.
plt.style.use("ggplot")

fig , axs = plt.subplots() 

sns.lineplot(
    data = df_plot,
    x="Year",
    y="Annual CO₂ emissions_x",
    hue="Entity",
    ax=axs,
)
plt.title("Annual CO₂ emissions per Countries")
#plt.savefig("annual CO₂ emissions per Countries")
# Out:
# Text(0.5, 1.0, 'Annual CO₂ emissions per Countries')

# %%
#Anual methane emissions per country.

#Select the countries to be displayed.
#Place holder
countries = ["Canada", "United States", "United Kingdom", "China", "Japan"]

#Plot the dataframe with the seleced entities.
df_plot = df[(df["Entity"].isin(countries))]

#Select the style of the graph.
plt.style.use("ggplot")

fig , axs = plt.subplots() 

sns.lineplot(
    data = df_plot,
    x="Year",
    y="Annual methane emissions",
    hue="Entity",
    ax=axs,
)

plt.title("Annual Methane Emissions per Country")
#plt.savefig("annual methane emissions per Countries")
# Out:
# Text(0.5, 1.0, 'Annual Methane Emissions per Country')

# %%
#Anual nitrous-oxide and emissions per country.

#Select the countries to be displayed.
#Place holder
countries = ["Canada", "United States", "United Kingdom", "China", "Japan"]

#Plot the dataframe with the seleced entities.
df_plot = df[(df["Entity"].isin(countries))]

#Select the style of the graph.
plt.style.use("ggplot")

fig , axs = plt.subplots() 

sns.lineplot(
    data = df_plot,
    x="Year",
    y="Annual nitrous oxide emissions",
    hue="Entity",
    ax=axs,
)

plt.title("Annual Nitrous-Oxide Emissions per Countries")
#plt.savefig("annual nitrous-oxide emissions per Countries")
# Out:
# Text(0.5, 1.0, 'Annual Nitrous-Oxide Emissions per Countries')

# %%
#Generate graph for the annual Nitrous-Oxide Emissions per population.

#Select the countries to be displayed.
#Place holder
countries = ["Canada", "United States", "United Kingdom", "China", "Japan"]

#Plot the dataframe with the seleced entities.
df = df[(df["Entity"].isin(countries))]

#Select the style of the graph.
plt.style.use("ggplot")

fig , axs = plt.subplots() 

sns.lineplot(
    data = df,
    x="Year",
    y="Nitrous oxide per population",
    hue="Entity",
    ax=axs,
)

plt.title("Annual Nitrous-Oxide Emissions per Population")
#plt.savefig("annual nitrous-oxide emissions per Population")
# Out:
# Text(0.5, 1.0, 'Annual Nitrous-Oxide Emissions per Population')

# %%
#Generate graph for the annual Methane Emissions per population.

#Select the countries to be displayed.
#Place holder
countries = ["Canada", "United States", "United Kingdom", "China", "Japan"]

#Plot the dataframe with the seleced entities.
df = df[(df["Entity"].isin(countries))]

#Select the style of the graph.
plt.style.use("ggplot")

fig , axs = plt.subplots() 

sns.lineplot(
    data = df,
    x="Year",
    y="Methane per population",
    hue="Entity",
    ax=axs,
)

plt.title("Annual Methane Emissions per Population")
#plt.savefig("annual methane emissions per Population")
# Out:
# Text(0.5, 1.0, 'Annual Methane Emissions per Population')
